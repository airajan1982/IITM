# %%
#!/usr/bin/env python3 and import pandas and numpy
import pandas as pd
import numpy as np

# %%
# Load the dataset

path = "D:/Learning/IITM/Week3/anime_data.csv"
data = pd.read_csv(path)

# %%
# data
data
# Out:
#                                                    title  \
# 0                       Fullmetal Alchemist: Brotherhood
# 1                                             your name.
# 2                                         A Silent Voice
# 3      Haikyuu!! Karasuno High School vs Shiratorizaw...
# 4                    Attack on Titan 3rd Season: Part II
# ...                                                  ...
# 12096  Sore Ike! Anpanman: Kirameke! Ice no Kuni no V...
# 12097                               Hulaing Babies Petit
# 12098                          Marco & The Galaxy Dragon
# 12099                          Xing Chen Bian 2nd Season
# 12100        Ultra B: Black Hole kara no Dokusaisha BB!!
#
#                                              description mediaType  eps  \
# 0      The foundation of alchemy is based on the law ...        TV   64
# 1      Mitsuha and Taki are two total strangers livin...     Movie    1
# ...

# %%
# validate null values
data.isnull().sum()
# Out:
# title                            0
# description                   4468
# mediaType                        0
# eps                              0
# duration                      4636
# ongoing                          0
# sznOfRelease                     0
# years_running                    0
# studio_primary                   0
# studios_colab                    0
# contentWarn                      0
# watched                          0
# watching                         0
# wantWatch                        0
# dropped                          0
# rating                           0
# votes                            0
# tag_Based_on_a_Manga             0
# tag_Comedy                       0
# tag_Action                       0
# tag_Fantasy                      0
# tag_Sci_Fi                       0
# tag_Shounen                      0
# tag_Original_Work                0
# tag_Non_Human_Protagonists       0
# tag_Drama                        0
# tag_Adventure                    0
# ...

# %%
# data types value counts
data.dtypes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of title                             str
# description                       str
# mediaType                         str
# eps                             int64
# duration                      float64
# ongoing                          bool
# sznOfRelease                      str
# years_running                   int64
# studio_primary                    str
# studios_colab                   int64
# contentWarn                     int64
# watched                       float64
# watching                        int64
# wantWatch                       int64
# dropped                         int64
# rating                        float64
# votes                           int64
# tag_Based_on_a_Manga            int64
# tag_Comedy                      int64
# tag_Action                      int64
# tag_Fantasy                     int64
# tag_Sci_Fi                      int64
# tag_Shounen                     int64
# ...

# %%
data.describe().T
# Out:
#                               count         mean          std     min     25%  \
# eps                         12101.0    13.393356    57.925097   1.000   1.000
# duration                     7465.0    24.230141    31.468171   1.000   4.000
# years_running               12101.0     0.283200     1.152234   0.000   0.000
# studios_colab               12101.0     0.051649     0.221326   0.000   0.000
# contentWarn                 12101.0     0.115362     0.319472   0.000   0.000
# watched                     12101.0  2862.605694  7724.347024   0.000  55.000
# watching                    12101.0   256.334435  1380.840902   0.000   2.000
# wantWatch                   12101.0  1203.681431  2294.327380   0.000  49.000
# dropped                     12101.0   151.568383   493.931710   0.000   3.000
# rating                      12101.0     2.949037     0.827385   0.844   2.304
# votes                       12101.0  2088.124700  5950.332228  10.000  34.000
# ...

# %%
#fetch titile where no of eps ==1
data[data['eps']==1]['title'].tolist()
# Out:
# ['your name.',
#  'A Silent Voice',
#  'Gintama Kanketsu-hen: Yorozuya yo Eien Nare',
#  'Spirited Away',
#  'Wolf Children',
#  'Rascal Does Not Dream of a Dreaming Girl',
#  "Howl's Moving Castle",
#  'Kizumonogatari Movie 3: Reiketsu',
#  'Princess Mononoke',
#  'Weathering With You',
#  'Luo Xiao Hei Zhan Ji Movie',
#  'KonoSuba – God’s blessing on this wonderful world! Movie: Legend of Crimson',
#  'Mushishi Zoku Shou: Suzu no Shizuku',
#  'Mushishi: Hihamukage',
#  'The Disappearance of Haruhi Suzumiya',
#  'The Garden of Sinners Movie 5: Paradox Paradigm',
#  'I Want to Eat Your Pancreas',
#  'Hotarubi no Mori e',
#  'Mushishi Zoku Shou: Odoro no Michi',
#  'Kizumonogatari Movie 2: Nekketsu',
#  'Violet Evergarden: Eternity and the Auto Memory Doll',
#  "Natsume's Book of Friends Movie: Ephemeral Bond",
#  'Youjo Senki: Saga of Tanya the Evil Movie',
#  'Steins;Gate Movie: Load Region of Deja Vu',
#  'The Boy and the Beast',
#  'Made in Abyss Movie: Dawn of the Deep Soul',
# ...

# %%
# unique media types
data['mediaType'].unique()
# Out:
# <ArrowStringArray>
# [         'TV',       'Movie',         'Web',  'TV Special',         'OVA',
#   'is_missing', 'DVD Special',       'Other', 'Music Video']
# Length: 9, dtype: str

# %%
# which title are bassed on which mediatype or how many titles for each mediatype
data.groupby('mediaType')['title'].count()
# Out:
# mediaType
# DVD Special     803
# Movie          1928
# Music Video    1290
# OVA            1770
# Other           580
# TV             3993
# TV Special      504
# Web            1170
# is_missing       63
# Name: title, dtype: int64

# %%
data['mediaType'].value_counts()
# Out:
# mediaType
# TV             3993
# Movie          1928
# OVA            1770
# Music Video    1290
# Web            1170
# DVD Special     803
# Other           580
# TV Special      504
# is_missing       63
# Name: count, dtype: int64

# %%
#data columns
data.columns
# Out:
# Index(['title', 'description', 'mediaType', 'eps', 'duration', 'ongoing',
#        'sznOfRelease', 'years_running', 'studio_primary', 'studios_colab',
#        'contentWarn', 'watched', 'watching', 'wantWatch', 'dropped', 'rating',
#        'votes', 'tag_Based_on_a_Manga', 'tag_Comedy', 'tag_Action',
#        'tag_Fantasy', 'tag_Sci_Fi', 'tag_Shounen', 'tag_Original_Work',
#        'tag_Non_Human_Protagonists', 'tag_Drama', 'tag_Adventure',
#        'tag_Family_Friendly', 'tag_Short_Episodes', 'tag_School_Life',
#        'tag_Romance', 'tag_Shorts', 'tag_Slice_of_Life', 'tag_Seinen',
#        'tag_Supernatural', 'tag_Magic', 'tag_Animal_Protagonists', 'tag_Ecchi',
#        'tag_Mecha', 'tag_Based_on_a_Light_Novel', 'tag_CG_Animation',
#        'tag_Superpowers', 'tag_Others', 'tag_missing'],
#       dtype='str')

# %%
data['studio_primary'].value_counts()
# Out:
# studio_primary
# Others                  4340
# is_missing              3208
# Toei Animation           636
# Sunrise                  430
# J.C. Staff               341
# MADHOUSE                 337
# TMS Entertainment        317
# Production I.G           271
# Studio Deen              260
# Studio Pierrot           221
# OLM                      210
# A-1 Pictures             194
# AIC                      167
# Shin-Ei Animation        164
# Nippon Animation         145
# Tatsunoko Production     144
# DLE                      130
# GONZO                    124
# Bones                    121
# Shaft                    118
# XEBEC                    117
# Kyoto Animation          106
# Name: count, dtype: int64

# %%
data['sznOfRelease'].value_counts()
# Out:
# sznOfRelease
# is_missing    8554
# Spring        1135
# Fall          1011
# Winter         717
# Summer         684
# Name: count, dtype: int64

# %%
#retrive the data of sznOfRelease in spring and studio_primary sunrise
data[(data['sznOfRelease'] == 'Spring') & (data['studio_primary'] == 'Sunrise')]
# Out:
#                                                    title  \
# 12               Code Geass: Lelouch of the Rebellion R2
# 21                                              Gintama'
# 62                                          Cowboy Bebop
# 306                                              Gintama
# 522    Mobile Suit Gundam: The Origin - Advent of the...
# 730                                        Tiger & Bunny
# 867                     Love Live! School Idol Project 2
# 1201                                 Banner of the Stars
# 1506            GaoGaiGar FINAL Grand Glorious Gathering
# 1560                            The Vision of Escaflowne
# 1675                                         Accel World
# 1752                                           Sgt. Frog
# 2215                                            Zegapain
# 2246                  Mobile Suit Gundam Unicorn RE:0096
# 2292                         Phi Brain: Kami no Puzzle 2
# ...

# %%
#find which movie is most watched in the dataset
data.sort_values(by='watched', ascending=False)[['title', 'watched']].head(1)
# Out:
#          title   watched
# 97  Death Note  161567.0

# %%
# figure how many title watched by more than 100/ 100?
data[data['watched'] >= 100].shape[0]
# Out:
# 8114

# %%
#watched > 100 and rating > 3.5
data[(data['watched'] > 100) & (data['rating'] > 3.5)].shape[0]
# Out:
# 3363
