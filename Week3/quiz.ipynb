# %%
import math 
print(math.factorial(4)) 
print(math.sqrt(49))
# Out:
# 24
# 7.0

# %%
import pandas as pd 
data = {"Name": ["Amit", "Priya"], "Age": [30, 25]} 
df = pd.DataFrame(data) 
print(df.iloc[1]["Name"])
# Out:
# Priya
