# %%
# In this notebook, we will demonstrate how to handle exceptions in Python. The following code snippet will raise a ZeroDivisionError because we are attempting to divide by zero.

try:
    i = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
try:
    raise ValueError("This is a custom error message.")
except ValueError as e:
    print(f"Caught an exception: {e}")
finally:
    print("This block will always execute, regardless of whether an exception occurred or not.")    

# Traceback (most recent call last):
#   File "<ipython-input-1-3f8e4b5c6d>", line 2, in <module>
#     raise ValueError("This is a custom error message.")
# ValueError: This is a custom error message.
# Out:
# Caught an exception: This is a custom error message.
# This block will always execute, regardless of whether an exception occurred or not.
